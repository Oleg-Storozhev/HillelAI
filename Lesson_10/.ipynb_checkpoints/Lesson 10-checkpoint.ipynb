# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier


sns.set(rc={'figure.figsize':(10, 8)})

# %% [markdown]
#     1. Загружаем датасеты

# %%
df1 = pd.read_csv('identity_small.csv', sep =',')
df1
# Out:
#         TransactionID  id_04  id_20  id_24      id_33     id_29  id_22  \
# 0             2987004    NaN  144.0    NaN  2220x1080  NotFound    NaN
# 1             2987008    NaN  500.0    NaN   1334x750  NotFound    NaN
# 2             2987010    0.0  142.0    NaN        NaN     Found    NaN
# 3             2987011    NaN  507.0    NaN        NaN  NotFound    NaN
# 4             2987016    0.0  575.0    NaN   1280x800     Found    NaN
# ...               ...    ...    ...    ...        ...       ...    ...
# 144228        3577521    0.0  139.0    NaN        NaN     Found    NaN
# 144229        3577526    NaN  333.0    NaN    855x480  NotFound    NaN
# 144230        3577529    NaN  411.0    NaN        NaN  NotFound    NaN
# 144231        3577531    0.0  368.0    NaN  2560x1600     Found    NaN
# 144232        3577534    NaN  595.0    NaN        NaN  NotFound    NaN
#
#            id_02
# 0        70787.0
# 1        98945.0
# 2       191631.0
# 3       221832.0
# 4         7460.0
# ...          ...
# 144228  145955.0
# 144229  172059.0
# 144230  632381.0
# 144231   55528.0
# 144232  339406.0
#
# [144233 rows x 8 columns]

# %%
df2 = pd.read_csv('trans_small.csv', sep =',')
df2
# Out:
#         TransactionID    D4  card1  card2  card3  addr1  addr2  \
# 0             2987000   NaN  13926    NaN  150.0  315.0   87.0
# 1             2987001   0.0   2755  404.0  150.0  325.0   87.0
# 2             2987002   0.0   4663  490.0  150.0  330.0   87.0
# 3             2987003  94.0  18132  567.0  150.0  476.0   87.0
# 4             2987004   NaN   4497  514.0  150.0  420.0   87.0
# ...               ...   ...    ...    ...    ...    ...    ...
# 590535        3577535   NaN   6550    NaN  150.0  272.0   87.0
# 590536        3577536   0.0  10444  225.0  150.0  204.0   87.0
# 590537        3577537   0.0  12037  595.0  150.0  231.0   87.0
# 590538        3577538  22.0   7826  481.0  150.0  387.0   87.0
# 590539        3577539   1.0  15066  170.0  150.0  299.0   87.0
#
#         TransactionAmt  isFraud   C13  ...  V225  V277  V243  V40  V46  V244  \
# 0                68.50        0   1.0  ...   NaN   NaN   NaN  NaN  NaN   NaN
# 1                29.00        0   1.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 2                59.00        0   1.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 3                50.00        0  25.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 4                50.00        0   1.0  ...   0.0   0.0   1.0  NaN  NaN   1.0
# ...                ...      ...   ...  ...   ...   ...   ...  ...  ...   ...
# 590535           49.00        0   3.0  ...   NaN   NaN   NaN  NaN  NaN   NaN
# 590536           39.50        0   1.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 590537           30.95        0   1.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 590538          117.00        0   5.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
# 590539          279.95        0   1.0  ...   NaN   NaN   NaN  0.0  1.0   NaN
#
#         V274  V73  V147   M5
# 0        NaN  0.0   NaN    F
# 1        NaN  0.0   NaN    T
# 2        NaN  0.0   NaN    F
# 3        NaN  0.0   NaN    T
# 4        0.0  NaN   0.0  NaN
# ...      ...  ...   ...  ...
# 590535   NaN  0.0   NaN    T
# 590536   NaN  0.0   NaN    F
# 590537   NaN  0.0   NaN  NaN
# 590538   NaN  0.0   NaN    F
# 590539   NaN  0.0   NaN  NaN
#
# [590540 rows x 23 columns]

# %% [markdown]
#     Объеденяем их

# %%
df = df2.set_index('TransactionID').join(df1.set_index('TransactionID'))
df
# Out:
#                  D4  card1  card2  card3  addr1  addr2  TransactionAmt  \
# TransactionID
# 2987000         NaN  13926    NaN  150.0  315.0   87.0           68.50
# 2987001         0.0   2755  404.0  150.0  325.0   87.0           29.00
# 2987002         0.0   4663  490.0  150.0  330.0   87.0           59.00
# 2987003        94.0  18132  567.0  150.0  476.0   87.0           50.00
# 2987004         NaN   4497  514.0  150.0  420.0   87.0           50.00
# ...             ...    ...    ...    ...    ...    ...             ...
# 3577535         NaN   6550    NaN  150.0  272.0   87.0           49.00
# 3577536         0.0  10444  225.0  150.0  204.0   87.0           39.50
# 3577537         0.0  12037  595.0  150.0  231.0   87.0           30.95
# 3577538        22.0   7826  481.0  150.0  387.0   87.0          117.00
# 3577539         1.0  15066  170.0  150.0  299.0   87.0          279.95
#
#                isFraud   C13   D10  ...  V73  V147   M5  id_04  id_20  id_24  \
# TransactionID                       ...
# 2987000              0   1.0  13.0  ...  0.0   NaN    F    NaN    NaN    NaN
# 2987001              0   1.0   0.0  ...  0.0   NaN    T    NaN    NaN    NaN
# 2987002              0   1.0   0.0  ...  0.0   NaN    F    NaN    NaN    NaN
# 2987003              0  25.0  84.0  ...  0.0   NaN    T    NaN    NaN    NaN
# 2987004              0   1.0   NaN  ...  NaN   0.0  NaN    NaN  144.0    NaN
# ...                ...   ...   ...  ...  ...   ...  ...    ...    ...    ...
# 3577535              0   3.0  56.0  ...  0.0   NaN    T    NaN    NaN    NaN
# 3577536              0   1.0   0.0  ...  0.0   NaN    F    NaN    NaN    NaN
# 3577537              0   1.0   0.0  ...  0.0   NaN  NaN    NaN    NaN    NaN
# 3577538              0   5.0  22.0  ...  0.0   NaN    F    NaN    NaN    NaN
# 3577539              0   1.0   1.0  ...  0.0   NaN  NaN    NaN    NaN    NaN
#
#                    id_33     id_29  id_22    id_02
# TransactionID
# 2987000              NaN       NaN    NaN      NaN
# 2987001              NaN       NaN    NaN      NaN
# 2987002              NaN       NaN    NaN      NaN
# 2987003              NaN       NaN    NaN      NaN
# 2987004        2220x1080  NotFound    NaN  70787.0
# ...                  ...       ...    ...      ...
# 3577535              NaN       NaN    NaN      NaN
# 3577536              NaN       NaN    NaN      NaN
# 3577537              NaN       NaN    NaN      NaN
# 3577538              NaN       NaN    NaN      NaN
# 3577539              NaN       NaN    NaN      NaN
#
# [590540 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   D4              421618 non-null  float64
#  1   card1           590540 non-null  int64
#  2   card2           581607 non-null  float64
#  3   card3           588975 non-null  float64
#  4   addr1           524834 non-null  float64
#  5   addr2           524834 non-null  float64
#  6   TransactionAmt  590540 non-null  float64
#  7   isFraud         590540 non-null  int64
#  8   C13             590540 non-null  float64
#  9   D10             514518 non-null  float64
#  10  D1              589271 non-null  float64
#  11  D4.1            421618 non-null  float64
#  12  V225            130430 non-null  float64
#  13  V277            130430 non-null  float64
#  14  V243            130430 non-null  float64
#  15  V40             421571 non-null  float64
#  16  V46             421571 non-null  float64
#  17  V244            130430 non-null  float64
#  18  V274            130430 non-null  float64
#  19  V73             513444 non-null  float64
#  20  V147            81945 non-null   float64
#  21  M5              240058 non-null  object
#  22  id_04           66324 non-null   float64
#  23  id_20           139261 non-null  float64
#  24  id_24           4747 non-null    float64
#  25  id_33           73289 non-null   object
#  26  id_29           140978 non-null  object
#  27  id_22           5169 non-null    float64
#  28  id_02           140872 non-null  float64
# dtypes: float64(24), int64(2), object(3)
# memory usage: 155.2+ MB

# %%
df.describe(include = "all").T
# Out:
#                  count unique        top    freq       mean       std    min  \
# D4              421618    NaN        NaN     NaN    140.002   191.097   -122
# card1           590540    NaN        NaN     NaN    9898.73   4901.17   1000
# card2           581607    NaN        NaN     NaN    362.555   157.793    100
# card3           588975    NaN        NaN     NaN    153.195   11.3364    100
# addr1           524834    NaN        NaN     NaN    290.734   101.741    100
# addr2           524834    NaN        NaN     NaN    86.8006   2.69062     10
# TransactionAmt  590540    NaN        NaN     NaN    135.027   239.163  0.251
# isFraud         590540    NaN        NaN     NaN    0.03499  0.183755      0
# C13             590540    NaN        NaN     NaN    32.5399   129.365      0
# D10             514518    NaN        NaN     NaN    123.982   182.615      0
# D1              589271    NaN        NaN     NaN    94.3476    157.66      0
# D4.1            421618    NaN        NaN     NaN    140.002   191.097   -122
# V225            130430    NaN        NaN     NaN   0.191758   1.29082      0
# V277            130430    NaN        NaN     NaN    51.9566   732.145      0
# V243            130430    NaN        NaN     NaN    1.17839   1.39895      0
# V40             421571    NaN        NaN     NaN   0.177145  0.505786      0
# V46             421571    NaN        NaN     NaN    1.02229  0.166719      0
# V244            130430    NaN        NaN     NaN    1.11856  0.698807      0
# V274            130430    NaN        NaN     NaN    107.152   1258.73      0
# V73             513444    NaN        NaN     NaN   0.139982  0.367098      0
# V147             81945    NaN        NaN     NaN   0.168601  0.750497      0
# M5              240058      2          F  132491        NaN       NaN    NaN
# id_04            66324    NaN        NaN     NaN -0.0589379  0.701015    -28
# id_20           139261    NaN        NaN     NaN    403.883    152.16    100
# id_24             4747    NaN        NaN     NaN    12.8009   2.37245     11
# id_33            73289    260  1920x1080   16874        NaN       NaN    NaN
# id_29           140978      2      Found   74926        NaN       NaN    NaN
# id_22             5169    NaN        NaN     NaN    16.0027   6.89766     10
# id_02           140872    NaN        NaN     NaN     174717    159652      1
#
#                    25%     50%     75%      max
# D4                   0      26     253      869
# card1             6019    9678   14184    18396
# card2              214     361     512      600
# card3              150     150     150      231
# addr1              204     299     330      540
# addr2               87      87      87      102
# TransactionAmt  43.321  68.769     125  31937.4
# isFraud              0       0       0        1
# C13                  1       3      12     2918
# D10                  0      15     197      876
# D1                   0       3     122      640
# D4.1                 0      26     253      869
# V225                 0       0       0       51
# V277                 0       0       0   104060
# V243                 1       1       1       57
# V40                  0       0       0       24
# V46                  1       1       1        6
# V244                 1       1       1       22
# V274                 0       0       0    66000
# V73                  0       0       0        7
# V147                 0       0       0       26
# M5                 NaN     NaN     NaN      NaN
# id_04                0       0       0        0
# id_20              256     472     533      661
# id_24               11      11      15       26
# id_33              NaN     NaN     NaN      NaN
# id_29              NaN     NaN     NaN      NaN
# id_22               14      14      14       44
# id_02            67992  125800  228749   999595

# %% [markdown]
#     По таблице видно что у нас есть колонки Nan в датасете. Проанализируем сколько их, где их больше

# %%
s = df.isna().sum()
s = s[s != 0].sort_values(ascending=False)
s
# Out:
# id_24    585793
# id_22    585371
# id_04    524216
# id_33    517251
# V147     508595
# V243     460110
# V225     460110
# V274     460110
# V244     460110
# V277     460110
# id_20    451279
# id_02    449668
# id_29    449562
# M5       350482
# V46      168969
# V40      168969
# D4.1     168922
# D4       168922
# V73       77096
# D10       76022
# addr2     65706
# addr1     65706
# card2      8933
# card3      1565
# D1         1269
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(24,24))         # Sample figsize in inches

corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns,
            yticklabels=corr.columns, annot = True,
            linewidths=.5, 
            ax=ax);

# %% [markdown]
#     Найдем все категориальные признаки

# %%
cols = df.columns
num_cols = df._get_numeric_data().columns
cols_obj = list(set(cols) - set(num_cols))
cols_obj
# Out:
# ['M5', 'id_29', 'id_33']

# %%
label_encoder = LabelEncoder()

df_new = df.copy()

for i in cols_obj:
    df_new[i] = label_encoder.fit_transform(df_new[i].tolist())


fig, ax = plt.subplots(figsize=(24,24))         # Sample figsize in inches

corr = df_new.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns,
            yticklabels=corr.columns, annot = True,
            linewidths=.5, 
            ax=ax);

# %%
list_of_col = ['isFraud', 'card3', 'D4', 'D10', 'D1', 'D4.1', 'V243', 'V40', 'V46', 'V244', 'V147', 'V73', 'id_04', 'id_20', 'id_24', 'id_29', 'id_22', 'id_02']
df.drop(df.columns.difference(list_of_col), 1, inplace = True)
df
# Out:
#                  D4  card3  isFraud   D10     D1  D4.1  V243  V40  V46  V244  \
# TransactionID
# 2987000         NaN  150.0        0  13.0   14.0   NaN   NaN  NaN  NaN   NaN
# 2987001         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 2987002         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 2987003        94.0  150.0        0  84.0  112.0  94.0   NaN  0.0  1.0   NaN
# 2987004         NaN  150.0        0   NaN    0.0   NaN   1.0  NaN  NaN   1.0
# ...             ...    ...      ...   ...    ...   ...   ...  ...  ...   ...
# 3577535         NaN  150.0        0  56.0   29.0   NaN   NaN  NaN  NaN   NaN
# 3577536         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 3577537         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 3577538        22.0  150.0        0  22.0   22.0  22.0   NaN  0.0  1.0   NaN
# 3577539         1.0  150.0        0   1.0    0.0   1.0   NaN  0.0  1.0   NaN
#
#                V73  V147  id_04  id_20  id_24     id_29  id_22    id_02
# TransactionID
# 2987000        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 2987001        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 2987002        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 2987003        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 2987004        NaN   0.0    NaN  144.0    NaN  NotFound    NaN  70787.0
# ...            ...   ...    ...    ...    ...       ...    ...      ...
# 3577535        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 3577536        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 3577537        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 3577538        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
# 3577539        0.0   NaN    NaN    NaN    NaN       NaN    NaN      NaN
#
# [590540 rows x 18 columns]

# %%
label_encoder = LabelEncoder()

df_new = df.copy()

cols_obj = ['id_29']

for i in cols_obj:
    df_new[i] = label_encoder.fit_transform(df_new[i].tolist())


fig, ax = plt.subplots(figsize=(24,24))         # Sample figsize in inches

corr = df_new.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns,
            yticklabels=corr.columns, annot = True,
            linewidths=.5, 
            ax=ax);

# %%
sns.countplot(x='isFraud', hue= 'id_29' ,data = df);

# %%
df1 = df.groupby('id_29')['isFraud'].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x = 'id_29', y = 'percent', hue = 'isFraud', kind = 'bar', data = df1)
g.ax.set_ylim(0,100)

for p in g.ax.patches:
    txt = str(p.get_height().round(2)) + '%'
    txt_x = p.get_x() 
    txt_y = p.get_height()
    g.ax.text(txt_x,txt_y,txt)

# %%
sns.scatterplot(x = 'D10', y = 'id_02', hue = 'isFraud' ,data=df);

# %% [markdown]
#     3.Logistic Regression

# %%
for i in cols_obj:
    df[i] = label_encoder.fit_transform(df_new[i].tolist())

df
# Out:
#                  D4  card3  isFraud   D10     D1  D4.1  V243  V40  V46  V244  \
# TransactionID
# 2987000         NaN  150.0        0  13.0   14.0   NaN   NaN  NaN  NaN   NaN
# 2987001         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 2987002         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 2987003        94.0  150.0        0  84.0  112.0  94.0   NaN  0.0  1.0   NaN
# 2987004         NaN  150.0        0   NaN    0.0   NaN   1.0  NaN  NaN   1.0
# ...             ...    ...      ...   ...    ...   ...   ...  ...  ...   ...
# 3577535         NaN  150.0        0  56.0   29.0   NaN   NaN  NaN  NaN   NaN
# 3577536         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 3577537         0.0  150.0        0   0.0    0.0   0.0   NaN  0.0  1.0   NaN
# 3577538        22.0  150.0        0  22.0   22.0  22.0   NaN  0.0  1.0   NaN
# 3577539         1.0  150.0        0   1.0    0.0   1.0   NaN  0.0  1.0   NaN
#
#                V73  V147  id_04  id_20  id_24  id_29  id_22    id_02
# TransactionID
# 2987000        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 2987001        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 2987002        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 2987003        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 2987004        NaN   0.0    NaN  144.0    NaN      1    NaN  70787.0
# ...            ...   ...    ...    ...    ...    ...    ...      ...
# 3577535        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 3577536        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 3577537        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 3577538        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
# 3577539        0.0   NaN    NaN    NaN    NaN      2    NaN      NaN
#
# [590540 rows x 18 columns]

# %%
scaler = StandardScaler()

X = df.drop(columns = ['isFraud'])
y = df['isFraud']

X.fillna(X.mean(), inplace = True)
y.fillna(y.mean(), inplace = True)

X_1 = scaler.fit_transform(X)
X_1
# Out:
# array([[-3.52040346e-16, -2.82202223e-01, -6.51089806e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16],
#        [-8.67057412e-01, -2.82202223e-01, -7.27355841e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16],
#        [-8.67057412e-01, -2.82202223e-01, -7.27355841e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16],
#        ...,
#        [-8.67057412e-01, -2.82202223e-01, -7.27355841e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16],
#        [-7.30807908e-01, -2.82202223e-01, -5.98290244e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16],
#        [-8.60864253e-01, -2.82202223e-01, -7.21489222e-01, ...,
#          5.24603148e-01,  5.50581396e-15,  3.73241690e-16]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_1, y, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression(random_state=42).fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.5522644804960408

# %% [markdown]
#     4.KNN

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = neigh.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.63605639359061

# %%
neigh = KNeighborsClassifier(n_neighbors=5).fit(X_train, y_train)
# Out:
# 0.63605639359061

# %%
y_pred = neigh.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.6225516012837674

# %% [markdown]
#     5.Gradient Boosting

# %%
model = XGBClassifier().fit(X_train, y_train)
# Out:
# [13:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_pred = model.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.6067888010964492

# %%
a = df[df['isFraud'] == 0].isFraud.count()
b = df[df['isFraud'] == 1].isFraud.count()
print("Is Not Fraud", a)
print("Is Fraud", b)
print("Is Not Fraud / is Fraud", a/b)
# Out:
# Is Not Fraud 569877
# Is Fraud 20663
# Is Not Fraud / is Fraud 27.579586700866283

# %%
model = XGBClassifier(scale_pos_weight = a/b).fit(X_train, y_train)
# Out:
# [14:04:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_pred = model.predict(X_test)
roc_auc_score(y_test, y_pred)
# Out:
# 0.7507236932419792

# %%
params={'booster': ['gbtree', 'dart']}
model = XGBClassifier(scale_pos_weight = a/b, use_rmm = 'true')
kf = KFold(n_splits=5, shuffle=True, random_state=42)

grid = GridSearchCV(model, params, cv=kf, scoring='roc_auc', n_jobs = -1)
grid.fit(X_train, y_train)
print("Найлучшее качество модели при", grid.best_params_)
print("Наилучшая оценка качества модели:", grid.best_score_)
# Out:
# [14:13:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Найлучшее качество модели при {'booster': 'gbtree'}
# Наилучшая оценка качества модели: 0.8191287727318726

# %% [markdown]
#     6. Random undersampling

# %%
steps = [('under', RandomUnderSampler(sampling_strategy = 'majority')), ('model', XGBClassifier(scale_pos_weight = a/b, use_rmm = 'true'))]
pipeline = Pipeline(steps=steps)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(pipeline, X_1, y, scoring='roc_auc', cv=kf, n_jobs=-1)
print(scores)
print(statistics.mean(scores))
# Out:
# [0.81314032 0.81169354 0.80750686 0.81048883 0.80758755]
# 0.8100834184657829

# %%
steps = [('under', RandomUnderSampler(sampling_strategy = 'all')), ('model', XGBClassifier(scale_pos_weight = a/b, use_rmm = 'true'))]
pipeline = Pipeline(steps=steps)
kf = KFold(n_splits=10, shuffle=True, random_state=42)

scores = cross_val_score(pipeline, X_1, y, scoring='roc_auc', cv=kf, n_jobs=-1)
print(scores)
print(statistics.mean(scores))
# Out:
# [0.81067446 0.81258634 0.81501347 0.81228352 0.80710742 0.81921721
#  0.80827417 0.82005343 0.80795289 0.80914569]
# 0.81223086169309

# %% [markdown]
#     7. SMOTE

# %%
steps = [('over', SMOTE()), ('model', XGBClassifier(scale_pos_weight = a/b, use_rmm = 'true'))]
pipeline = Pipeline(steps=steps)

scores = cross_val_score(pipeline, X_1, y, scoring='roc_auc', cv=kf, n_jobs=-1)
print(scores)
print(statistics.mean(scores))
# Out:
# [0.77729638 0.77914746 0.77943635 0.77441057 0.77396183 0.78463317
#  0.77285933 0.78503721 0.7737669  0.77375158]
# 0.7774300801310793
