# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv('true_car_listings_prepeared.csv')
df
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014  35725.0           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013      NaN  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013  48851.0           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014  39922.0           Windsor    CO  19VDE1F71EE003817
# 4           0  2016      NaN            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017      9.0       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017   3201.0         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016  28941.0      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017   3005.0       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017   2502.0          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# 2       Acura    ILX6-Speed
# 3       Acura    ILX5-Speed
# 4       Acura  ILXAutomatic
# ...       ...           ...
# 852117  Volvo         S90T6
# 852118  Volvo        XC90T6
# 852119  Volvo       XC90AWD
# 852120  Volvo           V90
# 852121  Volvo        XC90T8
#
# [852122 rows x 8 columns]

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014  35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013      NaN  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013  48851.0           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014  39922.0           Windsor    CO  19VDE1F71EE003817  Acura
# 4      0  2016      NaN            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
df['Price']
# Out:
# 0          8995
# 1         10888
# 2          8995
# 3         10999
# 4             0
#           ...
# 852117    63215
# 852118    72260
# 852119    55999
# 852120    60240
# 852121    76995
# Name: Price, Length: 852122, dtype: int64

# %%
df['Price'].iloc[0]
# Out:
# 8995

# %%
df.iloc[0]
# Out:
# Price                   8995
# Year                    2014
# Mileage              35725.0
# City                 El Paso
# State                     TX
# Vin        19VDE2E53EE000083
# Make                   Acura
# Model             ILX6-Speed
# Name: 0, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Price'])
# Out:
# pandas.core.series.Series

# %% [raw]
# Different Types

# %%
df.reset_index()
# Out:
#          index  Price  Year  Mileage              City State  \
# 0            0   8995  2014  35725.0           El Paso    TX
# 1            1  10888  2013      NaN  Long Island City    NY
# 2            2   8995  2013  48851.0           El Paso    TX
# 3            3  10999  2014  39922.0           Windsor    CO
# 4            4      0  2016      NaN            Lindon    UT
# ...        ...    ...   ...      ...               ...   ...
# 852117  852117  63215  2017      9.0       Culver City    CA
# 852118  852118  72260  2017   3201.0         Englewood    NJ
# 852119  852119  55999  2016  28941.0      Fort Collins    CO
# 852120  852120  60240  2017   3005.0       San Leandro    CA
# 852121  852121  76995  2017   2502.0          New York    NY
#
#                       Vin   Make         Model
# 0       19VDE2E53EE000083  Acura    ILX6-Speed
# 1       19VDE1F52DE012636  Acura    ILX5-Speed
# 2       19VDE2E52DE000025  Acura    ILX6-Speed
# 3       19VDE1F71EE003817  Acura    ILX5-Speed
# 4       19UDE2F32GA001284  Acura  ILXAutomatic
# ...                   ...    ...           ...
# 852117  YV1A22MK9H1013237  Volvo         S90T6
# 852118  YV4A22PL3H1186162  Volvo        XC90T6
# 852119  YV4A22PL4G1000868  Volvo       XC90AWD
# 852120  YV4A22NLXH1006162  Volvo           V90
# 852121  YV4BC0ZX1H1109845  Volvo        XC90T8
#
# [852122 rows x 9 columns]

# %%
df['Year'] == 2014
# Out:
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 852117    False
# 852118    False
# 852119    False
# 852120    False
# 852121    False
# Name: Year, Length: 852122, dtype: bool

# %%
df[df['Year'] == 2018]
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 6129    35721  2018      5.0          Littleton    CO  5J8TB4H37JL004139
# 6257        0  2018      5.0          Littleton    CO  5J8TB4H37JL005209
# 6258        0  2018      5.0          Littleton    CO  5J8TB4H34JL003045
# 6529    32995  2018      NaN           Cerritos    CA  19UUB1F30JA004453
# 6640    33929  2018    239.0    Hoffman Estates    IL  19UUB1F55JA000321
# ...       ...   ...      ...                ...   ...                ...
# 851987  59997  2018    248.0         Charleston    SC  YV4A22PL9J1207795
# 852038  46885  2018     15.0  Hasbrouck Heights    NJ  YV440MWK2J2044182
# 852066  51555  2018     30.0          Englewood    NJ  YV4102RL1J1004130
# 852073  52455  2018     10.0  Hasbrouck Heights    NJ  YV4A22RK8J1005471
# 852082  66240  2018     14.0           Nazareth    PA  LVY992ML7JP006733
#
#          Make   Model
# 6129    Acura     NaN
# 6257    Acura  RDXAWD
# 6258    Acura  RDXAWD
# 6529    Acura  TLXFWD
# 6640    Acura  TLXFWD
# ...       ...     ...
# 851987  Volvo  XC90T6
# 852038  Volvo     NaN
# 852066  Volvo  XC60T5
# 852073  Volvo  XC60T6
# 852082  Volvo   S90T6
#
# [922 rows x 8 columns]

# %%
df.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  7.311790e+05
# mean    20121.167199    2013.289145  5.251923e+04
# std     14123.100298       3.414987  4.203614e+04
# min         0.000000    1997.000000  5.000000e+00
# 25%     11997.000000    2012.000000  2.383600e+04
# 50%     17900.000000    2014.000000  4.026500e+04
# 75%     26397.000000    2016.000000  7.222700e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
x = df.drop('Price', axis = 1)
y = df['Price']
x
# Out:
#         Year  Mileage              City State                Vin   Make  \
# 0       2014  35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1       2013      NaN  Long Island City    NY  19VDE1F52DE012636  Acura
# 2       2013  48851.0           El Paso    TX  19VDE2E52DE000025  Acura
# 3       2014  39922.0           Windsor    CO  19VDE1F71EE003817  Acura
# 4       2016      NaN            Lindon    UT  19UDE2F32GA001284  Acura
# ...      ...      ...               ...   ...                ...    ...
# 852117  2017      9.0       Culver City    CA  YV1A22MK9H1013237  Volvo
# 852118  2017   3201.0         Englewood    NJ  YV4A22PL3H1186162  Volvo
# 852119  2016  28941.0      Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 852120  2017   3005.0       San Leandro    CA  YV4A22NLXH1006162  Volvo
# 852121  2017   2502.0          New York    NY  YV4BC0ZX1H1109845  Volvo
#
#                Model
# 0         ILX6-Speed
# 1         ILX5-Speed
# 2         ILX6-Speed
# 3         ILX5-Speed
# 4       ILXAutomatic
# ...              ...
# 852117         S90T6
# 852118        XC90T6
# 852119       XC90AWD
# 852120           V90
# 852121        XC90T8
#
# [852122 rows x 7 columns]

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
x['City']
# Out:
# 0                  El Paso
# 1         Long Island City
# 2                  El Paso
# 3                  Windsor
# 4                   Lindon
#                 ...
# 852117         Culver City
# 852118           Englewood
# 852119        Fort Collins
# 852120         San Leandro
# 852121            New York
# Name: City, Length: 852122, dtype: object

# %%
le.transform(x['City'])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/lv/4fp0098j7k584clypdt03q0r0000gn/T/ipykernel_16435/3286715136.py in <module>
# ----> 1 le.transform(x['City'])
#
# ~/PycharmProjects/HillelAI/venv2/lib/python3.8/site-packages/sklearn/preprocessing/_label.py in transform(self, y)
#     130         y : array-like of shape (n_samples,)
#     131         """
# --> 132         check_is_fitted(self)
#     133         y = column_or_1d(y, warn=True)
#     134         # transform of empty array is empty array
#
# ~/PycharmProjects/HillelAI/venv2/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/PycharmProjects/HillelAI/venv2/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This LabelEncoder instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
x = df.drop('Price', axis = 1)[["Year", "Mileage"]]
y = df['Price']
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isna().sum()
# Out:
# Price           0
# Year            0
# Mileage    120943
# City            0
# State           0
# Vin             0
# Make            0
# Model       77122
# dtype: int64

# %%
df.groupby('City')['Year'].count()
# Out:
# City
# AKRON            9
# ALEXANDRIA      70
# AURORA          49
# AUSTIN         349
# AVON             6
#               ...
# kansas city     85
# marietta        41
# phoenix         85
# salt lake       21
# victorville     68
# Name: Year, Length: 2553, dtype: int64

# %%
x = df.drop('Price', axis = 1)
y = df['Price']
y.iloc[0]
# Out:
# 8995

# %%
df.index
# Out:
# RangeIndex(start=0, stop=852122, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Price    852122 non-null  int64
#  1   Year     852122 non-null  int64
#  2   Mileage  731179 non-null  float64
#  3   City     852122 non-null  object
#  4   State    852122 non-null  object
#  5   Vin      852122 non-null  object
#  6   Make     852122 non-null  object
#  7   Model    775000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 52.0+ MB

# %%
df['Year'].array
# Out:
# <PandasArray>
# [2014, 2013, 2013, 2014, 2016, 2012, 2014, 2013, 2013, 2013,
#  ...
#  2017, 2017, 2017, 2017, 2017, 2017, 2017, 2016, 2017, 2017]
# Length: 852122, dtype: int64

# %%
x = df.Year
y = df.Price
plt.scatter(x, y)
